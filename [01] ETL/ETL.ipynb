# %%
import pandas as pd
import pyodbc
from sqlalchemy import create_engine
import urllib

# %%
cust = pd.read_csv(r'C:\Users\Karen Fernandes\anaconda3\Files\Global Electronics Retailer\cleaned_customers.csv')
cust.head()
# Out:
#    Unnamed: 0  customer_key  gender               name            city  \
# 0           0           301  Female      Lilly Harding  WANDEARAH EAST
# 1           1           325  Female       Madison Hull      MOUNT BUDD
# 2           2           554  Female      Claire Ferres       WINJALLOK
# 3           3           786    Male  Jai Poltpalingada    MIDDLE RIVER
# 4           4          1042    Male    Aidan Pankhurst   TAWONGA SOUTH
#
#   state_code              state zip_code    country  continent    birthday
# 0         SA    South Australia     5523  Australia  Australia  1939-07-03
# 1         WA  Western Australia     6522  Australia  Australia  1979-09-27
# 2        VIC           Victoria     3380  Australia  Australia  1947-05-26
# 3         SA    South Australia     5223  Australia  Australia  1957-09-17
# 4        VIC           Victoria     3698  Australia  Australia  1965-11-19

# %%
# drop Unnamed: 0 
cust = cust.drop('Unnamed: 0', axis=1)

# %%
sales = pd.read_csv(r'C:\Users\Karen Fernandes\anaconda3\Files\Global Electronics Retailer\cleaned_sales.csv')
sales.head()
# Out:
#    Unnamed: 0  order_number  line_item  order_date delivery_date  \
# 0           0        366000          1  2016-01-01           NaN
# 1           1        366001          1  2016-01-01    2016-01-13
# 2           2        366001          2  2016-01-01    2016-01-13
# 3           3        366002          1  2016-01-01    2016-01-12
# 4           4        366002          2  2016-01-01    2016-01-12
#
#    customer_key  store_key  product_key  quantity currency_code
# 0        265598         10         1304         1           CAD
# 1       1269051          0         1048         2           USD
# 2       1269051          0         2007         1           USD
# 3        266019          0         1106         7           CAD
# 4        266019          0          373         1           CAD

# %%
# drop Unnamed: 0 
sales = sales.drop('Unnamed: 0', axis=1)

# %%
stores = pd.read_csv(r'C:\Users\Karen Fernandes\anaconda3\Files\Global Electronics Retailer\cleaned_stores.csv')
stores.head()
# Out:
#    Unnamed: 0  store_key    country                         state  \
# 0           0          1  Australia  Australian Capital Territory
# 1           1          2  Australia            Northern Territory
# 2           2          3  Australia               South Australia
# 3           3          4  Australia                      Tasmania
# 4           4          5  Australia                      Victoria
#
#    square_meters   open_date
# 0          595.0  2008-01-01
# 1          665.0  2008-01-12
# 2         2000.0  2012-01-07
# 3         2000.0  2010-01-01
# 4         2000.0  2015-12-09

# %%
# drop Unnamed: 0 
stores = stores.drop('Unnamed: 0', axis=1)

# %%
prod = pd.read_csv(r'C:\Users\Karen Fernandes\anaconda3\Files\Global Electronics Retailer\cleaned_products.csv')
prod.head()
# Out:
#    Unnamed: 0  product_key                         product_name    brand  \
# 0           0            1  Contoso 512MB MP3 Player E51 Silver  Contoso
# 1           1            2    Contoso 512MB MP3 Player E51 Blue  Contoso
# 2           2            3     Contoso 1G MP3 Player E100 White  Contoso
# 3           3            4    Contoso 2G MP3 Player E200 Silver  Contoso
# 4           4            5       Contoso 2G MP3 Player E200 Red  Contoso
#
#     color  unit_cost_usd  unit_price_usd  subcategory_key subcategory  \
# 0  Silver           6.62           12.99              101     MP4&MP3
# 1    Blue           6.62           12.99              101     MP4&MP3
# 2   White           7.40           14.52              101     MP4&MP3
# 3  Silver          11.00           21.57              101     MP4&MP3
# 4     Red          11.00           21.57              101     MP4&MP3
#
#    category_key category
# 0             1    Audio
# 1             1    Audio
# 2             1    Audio
# 3             1    Audio
# 4             1    Audio

# %%
# drop Unnamed: 0 
prod = prod.drop('Unnamed: 0', axis=1)

# %%
rates = pd.read_csv(r'C:\Users\Karen Fernandes\anaconda3\Files\Global Electronics Retailer\cleaned_exchange_rates.csv')
rates.head()
# Out:
#    Unnamed: 0        date currency  exchange
# 0           0  2015-01-01      USD    1.0000
# 1           1  2015-01-01      CAD    1.1583
# 2           2  2015-01-01      AUD    1.2214
# 3           3  2015-01-01      EUR    0.8237
# 4           4  2015-01-01      GBP    0.6415

# %%
# drop Unnamed: 0 
rates = rates.drop('Unnamed: 0', axis=1)

# %%
server = 'LAPTOP-68P3K4HH\SQLEXPRESS'
database = 'Global_Retailer'
username = 'sa'
password = 'Ghkukikukmehaha6.'
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\Karen Fernandes\AppData\Local\Temp\ipykernel_20568\3698821013.py:1: SyntaxWarning: invalid escape sequence '\S'
#   server = 'LAPTOP-68P3K4HH\SQLEXPRESS'

# %%
# Create a connection string
connection_string = f"mssql+pyodbc://{username}:{urllib.parse.quote_plus(password)}@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server"
engine = create_engine(connection_string)

# %%
# Create a dictionary of DataFrames
dataframes = {
    'customers': cust,
    'sales': sales,
    'stores': stores,
    'products': prod,
    'exchange_rates': rates,
}

# %%
# Load each DataFrame into SQL
for table_name, df in dataframes.items():
    df.to_sql(table_name, con=engine, if_exists='replace', index=False)
